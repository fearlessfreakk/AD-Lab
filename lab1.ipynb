# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = " Hello, World! "
print(a.strip())
# Out:
# Hello, World!

# %%
a = "Hello, World!"
print(a.lower())
print(a.upper())
# Out:
# hello, world!
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.replace("o", "i"))
# Out:
# Helli, Wirld!

# %%
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)

txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 59 dollars
# The price is 1180 dollars

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
thislist = ["apple", "banana", "cherry"]
if "apple" in thislist:
    print("Yes, 'apple' is in the fruits list")
# Out:
# Yes, 'apple' is in the fruits list

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)

thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'melon', 'mango']
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
# Out:
# 'banana'

# %%
thislist = ["apple", "banana", "cherry"]
del thislist

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "Kiwi", "melon", "mango"]
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'apple', 'banana', 'cherry', 'kiwi', 'mango', 'melon', 'orange']

# %%
thislist = [234,532,24,532,14,9]
thislist.sort()
print(thislist)
# Out:
# [9, 14, 24, 234, 532, 532]

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# append
# clear
# copy
# count
# Index
# reverse
list1 = [1, 2, 3]
list1.append(4)
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
list1 = [1, 2, 3]
list1.clear()
print(list1)
# Out:
# []

# %%
list2 = [1, 2, 3]
list3 = list2.copy()
print(list3)
# Out:
# [1, 2, 3]

# %%
list1 = [1, 2, 2, 2, 2, 4, 3]
n = list1.count(2)
print(n)
# Out:
# 4

# %%
list1 = [1, 2, 2, 2, 2, 4, 3]
print(list1.index(3))
# Out:
# 6

# %%
list1 = [1, 2, 2, 2, 2, 4, 3]
list2.reverse()
print(list1)
# Out:
# [1, 2, 2, 2, 2, 4, 3]

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry", False, True, 0}
print(thisset)
# Out:
# {False, True, 'apple', 'banana', 'cherry'}

# %%
thisset = set(("apple", "banana", "cherry"))
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)
print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)
print(set1)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "facebook"}

set3 = set1.isdisjoint(set2)
print(set3)
# Out:
# True

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustsang', 'year': 1964}

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
x = thisdict.keys()
print(x)
y = thisdict.values()
print(y)
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_values(['Ford', 'Mustsang', 1964])

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964,
    "year" : 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustsang', 'year': 2020}

# %%
print(len(thisdict))
# Out:
# 3

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}

thisdict.update({"year" : 2020})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustsang', 'year': 2020}

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}

print(type(thisdict))
# Out:
# <class 'dict'>

# %%
car = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}

x = car.keys()
print(x)

car["color"] = "white"
print(x)
print(car)
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])
# {'brand': 'Ford', 'model': 'Mustsang', 'year': 1964, 'color': 'white'}

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}
if "model" in thisdict:
    print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
    "brand" : "Ford",
    "model" : "Mustsang",
    "year" : 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustsang'}

# %%
myfamily = {
    "child1" : {
        "name" : "Emil",
        "year" : 2004
    },
    "child2" : {
        "name" : "Tobias",
        "year" : 2007
    },
    "child3" : {
        "name" : "Linus",
        "year" : 2011
    },
}

print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}
