# %%
import pandas as pd

df = pd.read_csv('iris.csv')

print(df)
# Out:
#      Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm  \
# 0      1             5.1            3.5             1.4            0.2
# 1      2             4.9            3.0             1.4            0.2
# 2      3             4.7            3.2             1.3            0.2
# 3      4             4.6            3.1             1.5            0.2
# 4      5             5.0            3.6             1.4            0.2
# ..   ...             ...            ...             ...            ...
# 145  146             6.7            3.0             5.2            2.3
# 146  147             6.3            2.5             5.0            1.9
# 147  148             6.5            3.0             5.2            2.0
# 148  149             6.2            3.4             5.4            2.3
# 149  150             5.9            3.0             5.1            1.8
#
#              Species
# 0        Iris-setosa
# 1        Iris-setosa
# 2        Iris-setosa
# 3        Iris-setosa
# 4        Iris-setosa
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [150 rows x 6 columns]

# %%
# display max number of rows
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.aggregate(['sum', 'min'])
# Out:
#        Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm  \
# sum  11325           876.5          458.1           563.8          179.8
# min      1             4.3            2.0             1.0            0.1
#
#                                                Species
# sum   Iris-setosa Iris-setosa Iris-setosa Iris-seto...
# min                                        Iris-setosa

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
gk = df.groupby(' Species')
gk.first()
# Out:
#                  Id    SepalLengthCm   SepalWidthCm   PetalLengthCm  \
#  Species
# Iris-setosa        1             5.1            3.5             1.4
# Iris-versicolor   51             7.0            3.2             4.7
# Iris-virginica   101             6.3            3.3             6.0
#
#                   PetalWidthCm
#  Species
# Iris-setosa                0.2
# Iris-versicolor            1.4
# Iris-virginica             2.5

# %%
print(df.head(10))
# Out:
#    Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm  \
# 0    1             5.1            3.5             1.4            0.2
# 1    2             4.9            3.0             1.4            0.2
# 2    3             4.7            3.2             1.3            0.2
# 3    4             4.6            3.1             1.5            0.2
# 4    5             5.0            3.6             1.4            0.2
# 5    6             5.4            3.9             1.7            0.4
# 6    7             4.6            3.4             1.4            0.3
# 7    8             5.0            3.4             1.5            0.2
# 8    9             4.4            2.9             1.4            0.2
# 9   10             4.9            3.1             1.5            0.1
#
#         Species
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa
# 6   Iris-setosa
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa

# %%
print(df.head())
# Out:
#    Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm  \
# 0    1             5.1            3.5             1.4            0.2
# 1    2             4.9            3.0             1.4            0.2
# 2    3             4.7            3.2             1.3            0.2
# 3    4             4.6            3.1             1.5            0.2
# 4    5             5.0            3.6             1.4            0.2
#
#         Species
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa

# %%
print(df.tail())
# Out:
#      Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm  \
# 145  146             6.7            3.0             5.2            2.3
# 146  147             6.3            2.5             5.0            1.9
# 147  148             6.5            3.0             5.2            2.0
# 148  149             6.2            3.4             5.4            2.3
# 149  150             5.9            3.0             5.1            1.8
#
#              Species
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              150 non-null    int64
#  1    SepalLengthCm  150 non-null    float64
#  2    SepalWidthCm   150 non-null    float64
#  3    PetalLengthCm  150 non-null    float64
#  4    PetalWidthCm   150 non-null    float64
#  5    Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
df.describe()
# Out:
#               Id    SepalLengthCm   SepalWidthCm   PetalLengthCm  \
# count  150.000000      150.000000     150.000000      150.000000
# mean    75.500000        5.843333       3.054000        3.758667
# std     43.445368        0.828066       0.433594        1.764420
# min      1.000000        4.300000       2.000000        1.000000
# 25%     38.250000        5.100000       2.800000        1.600000
# 50%     75.500000        5.800000       3.000000        4.350000
# 75%    112.750000        6.400000       3.300000        5.100000
# max    150.000000        7.900000       4.400000        6.900000
#
#         PetalWidthCm
# count     150.000000
# mean        1.198667
# std         0.763161
# min         0.100000
# 25%         0.300000
# 50%         1.300000
# 75%         1.800000
# max         2.500000

# %%
df = pd.read_csv('iris.csv')
new_df = df.dropna()
print(new_df.to_string())
# Out:
#      Id    SepalLengthCm   SepalWidthCm   PetalLengthCm   PetalWidthCm           Species
# 0      1             5.1            3.5             1.4            0.2       Iris-setosa
# 1      2             4.9            3.0             1.4            0.2       Iris-setosa
# 2      3             4.7            3.2             1.3            0.2       Iris-setosa
# 3      4             4.6            3.1             1.5            0.2       Iris-setosa
# 4      5             5.0            3.6             1.4            0.2       Iris-setosa
# 5      6             5.4            3.9             1.7            0.4       Iris-setosa
# 6      7             4.6            3.4             1.4            0.3       Iris-setosa
# 7      8             5.0            3.4             1.5            0.2       Iris-setosa
# 8      9             4.4            2.9             1.4            0.2       Iris-setosa
# 9     10             4.9            3.1             1.5            0.1       Iris-setosa
# 10    11             5.4            3.7             1.5            0.2       Iris-setosa
# 11    12             4.8            3.4             1.6            0.2       Iris-setosa
# 12    13             4.8            3.0             1.4            0.1       Iris-setosa
# 13    14             4.3            3.0             1.1            0.1       Iris-setosa
# 14    15             5.8            4.0             1.2            0.2       Iris-setosa
# 15    16             5.7            4.4             1.5            0.4       Iris-setosa
# 16    17             5.4            3.9             1.3            0.4       Iris-setosa
# 17    18             5.1            3.5             1.4            0.3       Iris-setosa
# 18    19             5.7            3.8             1.7            0.3       Iris-setosa
# 19    20             5.1            3.8             1.5            0.3       Iris-setosa
# 20    21             5.4            3.4             1.7            0.2       Iris-setosa
# 21    22             5.1            3.7             1.5            0.4       Iris-setosa
# 119  120             6.0            2.2             5.0            1.5    Iris-virginica
# 120  121             6.9            3.2             5.7            2.3    Iris-virginica
# 121  122             5.6            2.8             4.9            2.0    Iris-virginica
# 122  123             7.7            2.8             6.7            2.0    Iris-virginica
# 123  124             6.3            2.7             4.9            1.8    Iris-virginica
# 124  125             6.7            3.3             5.7            2.1    Iris-virginica
# 125  126             7.2            3.2             6.0            1.8    Iris-virginica
# 126  127             6.2            2.8             4.8            1.8    Iris-virginica
# 127  128             6.1            3.0             4.9            1.8    Iris-virginica
# 128  129             6.4            2.8             5.6            2.1    Iris-virginica
# 129  130             7.2            3.0             5.8            1.6    Iris-virginica
# 130  131             7.4            2.8             6.1            1.9    Iris-virginica
# 131  132             7.9            3.8             6.4            2.0    Iris-virginica
# 132  133             6.4            2.8             5.6            2.2    Iris-virginica
# 133  134             6.3            2.8             5.1            1.5    Iris-virginica
# 134  135             6.1            2.6             5.6            1.4    Iris-virginica
# 135  136             7.7            3.0             6.1            2.3    Iris-virginica
# 136  137             6.3            3.4             5.6            2.4    Iris-virginica
# 137  138             6.4            3.1             5.5            1.8    Iris-virginica
# 138  139             6.0            3.0             4.8            1.8    Iris-virginica
# 139  140             6.9            3.1             5.4            2.1    Iris-virginica
# 140  141             6.7            3.1             5.6            2.4    Iris-virginica
# 141  142             6.9            3.1             5.1            2.3    Iris-virginica
# 142  143             5.8            2.7             5.1            1.9    Iris-virginica
# 143  144             6.8            3.2             5.9            2.3    Iris-virginica
# 144  145             6.7            3.3             5.7            2.5    Iris-virginica
# 145  146             6.7            3.0             5.2            2.3    Iris-virginica
# 146  147             6.3            2.5             5.0            1.9    Iris-virginica
# 147  148             6.5            3.0             5.2            2.0    Iris-virginica
# 148  149             6.2            3.4             5.4            2.3    Iris-virginica
# 149  150             5.9            3.0             5.1            1.8    Iris-virginica

# %%
print(df.columns)
# Out:
# Index(['Id ', ' SepalLengthCm', ' SepalWidthCm', ' PetalLengthCm',
#        ' PetalWidthCm', ' Species'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv('iris.csv')

df.plot()
# Out:
# <Axes: >

# %%
df.plot(x=" SepalWidthCm", y=" PetalLengthCm")
# Out:
# <Axes: xlabel=' SepalWidthCm'>

# %%
df.plot(subplots=True, figsize=(8, 8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import matplotlib.pyplot as plt
df.plot(x=" SepalWidthCm", y=[" PetalLengthCm"], kind='bar')
# Out:
# <Axes: xlabel=' SepalWidthCm'>

# %%
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot([0, 1, 2, 3, 4, 5]) 
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\3643114266.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\2878133669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[ 2.72249617 -1.00232938 -1.43241126]
#  [ 0.76161216  0.21071425 -1.87734723]]

# %%
sns.distplot(random.normal(size=(2,3)), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\2159542615.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=(2,3)), hist=False)

# %%
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\1308901639.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\2410585992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\3894723881.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\3894723881.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

# %%
sns.distplot(random.poisson(lam=2, size=1000), kde=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\3521096022.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %%
sns.distplot(random.uniform(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\1494691810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000), hist=False)

# %%
sns.distplot(random.logistic(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\1215292993.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False)

# %%
sns.distplot(random.exponential(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\4069225469.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False)

# %%
sns.distplot(random.chisquare(df=1, size=1000), hist=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\3315153496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)

# %%
sns.distplot(random.rayleigh(size=1000), hist=False )
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\2740879108.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=1000), hist=False )

# %%
sns.distplot(random.pareto(a=2, size=1000), kde=False)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27852\711828378.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.pareto(a=2, size=1000), kde=False)
